# %% [markdown]
# #Some warmup exercises

# %%
#Exercise: Create a class called "Person" that has an attribute for name and a method for printing the name.

# %%
#Exercise: Create a class called "Car" that has attributes for make, model, and year, as well as a method for honking the horn.

# %%
#Exercise: Create a class called "BankAccount" that has an attribute for the account owner's name and balance, as well as methods for depositing and withdrawing money.

# %%
#Exercise: Create a class called "Triangle" that has a method for calculating the area of the triangle using the base and height. 
#Use a @staticmethod decorator to indicate that the method doesn't need access to any class or instance level attribute.

# %%
#Exercise: Create a class called "Circle" that has a method for calculating the circumference of the circle using the radius. 
#Use a @classmethod decorator to indicate that the method needs access to the class level attribute, pi

# %%
#Execise: Create a python program to define a class and create an instance of the said class to finally print out the stored data in the namespaes of the instance
# to return the values stored in the namespaces on an instance of a class we use instance_name.__dict__

# solution

# %% [markdown]
# #Good stuff

# %%
# Exercise 2 Sometimes you don't know what to expect from the user input it maybe the case you don't have much idea about the number of 
# To set the name of the attribute like self.name we use __setattr__ inbuilt function to set the name of the variable and assign a value

class train:
  def __init__(self):
    pass
def updateparams(obj,args):
  for key,value in args.items():
    setattr(obj,key,value)

dict1 = {'Name' : 'ABC','Age': 34}
pass_1 =train()
# leverage the function above to add parameters to the pass_1 object write code below



#uncomment the part below to see if the pass_1 object has accepted the input and parameters are updated
# pass_1.__dict__

# %%
# Exercise 3 Its time to be creative, create a class of your choice but the catch is to have a class variable which stores the value of number of instance created
#solutiion1




#solution 2
